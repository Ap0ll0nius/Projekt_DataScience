# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD, LatentDirichletAllocation
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import numpy as np
from itertools import combinations
import re
import nltk

# Preprocessing Function
def preprocess_text(text):
    # Lowercase the text
    text = text.lower()
    # Remove punctuation and numbers
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text)
    text = ' '.join([word for word in tokens if word not in stop_words])
    return text

# Load Dataset
df = pd.read_csv("university_of_oxford_tripadvisor_reviews.csv")
df['cleaned_text'] = df['text'].apply(preprocess_text)

# Function to Calculate Coherence Scores
def compute_coherence_score(topics, matrix, vocab):
    # Compute co-occurrence matrix
    co_occurrence_matrix = np.dot(matrix.T, matrix)
    vocab_to_idx = {word: idx for idx, word in enumerate(vocab)}
    
    def topic_coherence(topic):
        coherence = 0
        n_pairs = 0
        for word1, word2 in combinations(topic, 2):
            idx1, idx2 = vocab_to_idx[word1], vocab_to_idx[word2]
            co_occurrence = co_occurrence_matrix[idx1, idx2]
            if co_occurrence > 0:
                coherence += np.log(co_occurrence + 1)  # +1 to avoid log(0)
                n_pairs += 1
        return coherence / n_pairs if n_pairs > 0 else 0
    
    return [topic_coherence(topic) for topic in topics]

# Function to Extract Topics
def extract_topics(model, vectorizer, n_top_words=5):
    vocab = vectorizer.get_feature_names_out()
    topics = []
    for idx, topic in enumerate(model.components_):
        top_words = [vocab[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
        topics.append(top_words)
        print(f"Topic {idx + 1}: {', '.join(top_words)}")
    return topics

# TF-IDF
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df['cleaned_text'])

# LSA with TF-IDF
lsa_tfidf_model = TruncatedSVD(n_components=10, random_state=42)
lsa_tfidf_model.fit(tfidf_matrix)

# Extract Topics
lsa_tfidf_topics = extract_topics(lsa_tfidf_model, tfidf_vectorizer)

# Compute Coherence
lsa_tfidf_coherence = compute_coherence_score(lsa_tfidf_topics, tfidf_matrix.toarray(), tfidf_vectorizer.get_feature_names_out())
for idx, score in enumerate(lsa_tfidf_coherence):
    print(f"LSA (TF-IDF) - Topic {idx + 1} Coherence Score: {score}")
# Out:
# Topic 1: oxford, university, colleges, visit, tour
# Topic 2: tour, guide, walking, took, interesting
# Topic 3: college, church, hall, christ, potter
# Topic 4: place, visit, history, great, harry
# Topic 5: around, walk, beautiful, lovely, buildings
# Topic 6: many, colleges, history, interesting, architecture
# Topic 7: city, place, see, visit, worth
# Topic 8: see, harry, potter, many, great
# Topic 9: one, time, architecture, day, love
# Topic 10: great, city, colleges, history, hop
# LSA (TF-IDF) - Topic 1 Coherence Score: 1.0176656573356944
# LSA (TF-IDF) - Topic 2 Coherence Score: 0.5744689777650245
# LSA (TF-IDF) - Topic 3 Coherence Score: 0.5577459740778256
# LSA (TF-IDF) - Topic 4 Coherence Score: 0.6388518810335293
# LSA (TF-IDF) - Topic 5 Coherence Score: 0.6005430706148802
# LSA (TF-IDF) - Topic 6 Coherence Score: 0.6405946265107512
# LSA (TF-IDF) - Topic 7 Coherence Score: 0.638896615215286
# LSA (TF-IDF) - Topic 8 Coherence Score: 0.5312828503913563
# LSA (TF-IDF) - Topic 9 Coherence Score: 0.3986270055054698
# LSA (TF-IDF) - Topic 10 Coherence Score: 0.5078190451877254
